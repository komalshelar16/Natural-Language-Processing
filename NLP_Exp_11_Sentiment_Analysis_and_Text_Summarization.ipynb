# %% [markdown]
# <a href="https://colab.research.google.com/github/komalshelar16/Natural-Language-Processing/blob/main/NLP_Exp_11_Sentiment_Analysis_and_Text_Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
# !pip install lxml

# %%
import bs4 as bs
import urllib.request
import re

# %%
import requests
url = "https://en.wikipedia.org/wiki/Climate_change"
headers = {"User-Agent":"Mozilla/5.0"
}
response = requests.get(url, headers=headers)
source = response.text

# %%
soup = bs.BeautifulSoup(source,'lxml')

# %%
text = ""
for paragraph in soup.find_all('p'):
  text += paragraph.text

# %%
text = re.sub(r'\[[0-9]*\]',' ',text)
text = re.sub(r'\s+',' ',text)
clean_text = text.lower()
clean_text = re.sub(r'\d',' ',clean_text)
clean_text = re.sub(r'\s+',' ',clean_text)

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt_tab')
sentences = nltk.sent_tokenize(text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
stop_words = nltk.corpus.stopwords.words('english')
word2count = {}
for word in nltk.word_tokenize(clean_text):
  if word not in stop_words:
    if word not in word2count.keys():
      word2count[word] = 1
    else:
      word2count[word] +=1

# %%
word2count
# Out:
# {'present-day': 1,
#  'climate': 160,
#  'change': 96,
#  'includes': 3,
#  'global': 75,
#  'warming—the': 1,
#  'ongoing': 2,
#  'increase': 25,
#  'average': 13,
#  'temperature—and': 1,
#  'wider': 1,
#  'effects': 13,
#  'earth': 29,
#  "'s": 36,
#  'system': 10,
#  '.': 547,
#  'broader': 1,
#  'sense': 1,
#  'also': 40,
#  'previous': 2,
#  'long-term': 5,
#  'changes': 24,
#  'modern-day': 1,
#  'rise': 15,
#  'temperatures': 12,
#  'driven': 3,
#  'human': 15,
#  'activities': 4,
#  ',': 502,
#  'especially': 1,
#  'fossil': 20,
#  'fuel': 12,
#  '(': 39,
#  'coal': 10,
#  'oil': 4,
#  'natural': 14,
#  'gas': 23,
#  ')': 39,
#  'burning': 3,
#  'since': 18,
#  'industrial': 10,
#  'revolution': 4,
#  'use': 23,
#  'deforestation': 7,
#  'agricultural': 10,
#  'practices': 2,
#  'release': 5,
#  'greenhouse': 40,
#  'gases': 30,
#  'absorb': 9,
#  'heat': 34,
#  'radiates': 2,
#  'warms': 2,
#  'sunlight': 14,
#  'warming': 89,
#  'lower': 7,
#  'atmosphere': 30,
# ...

# %%
for key in word2count.keys():
  word2count[key] = word2count[key]/max(word2count.values())

# %%
word2count
# Out:
# {'present-day': 0.0018281535648994515,
#  'climate': 0.29250457038391225,
#  'change': 0.17550274223034734,
#  'includes': 0.005484460694698354,
#  'global': 0.13711151736745886,
#  'warming—the': 0.0018281535648994515,
#  'ongoing': 0.003656307129798903,
#  'increase': 0.04570383912248629,
#  'average': 0.02376599634369287,
#  'temperature—and': 0.0018281535648994515,
#  'wider': 0.0018281535648994515,
#  'effects': 0.02376599634369287,
#  'earth': 0.05301645338208409,
#  "'s": 0.06581352833638025,
#  'system': 0.018281535648994516,
#  '.': 1.0,
#  'broader': 0.00199203187250996,
#  'sense': 0.00199203187250996,
#  'also': 0.0796812749003984,
#  'previous': 0.00398406374501992,
#  'long-term': 0.0099601593625498,
#  'changes': 0.04780876494023904,
#  'modern-day': 0.00199203187250996,
#  'rise': 0.029880478087649404,
#  'temperatures': 0.02390438247011952,
#  'driven': 0.00597609561752988,
#  'human': 0.029880478087649404,
#  'activities': 0.00796812749003984,
#  ',': 1.0,
# ...

# %%
sent2score = {}
for sentence in sentences:
  for word in nltk.word_tokenize(sentence.lower()):
    if word in word2count.keys():
      if len(sentence.split(' ')) < 25:
        if sentence not in sent2score.keys():
          sent2score[sentence] =word2count[word]
        else:
          sent2score[sentence] +=word2count[word]

# %%
import heapq
best_sentences = heapq.nlargest(5,sent2score,key=sent2score.get)

# %%
for sentence in best_sentences:
  print(sentence)
# Out:
# Of these emissions, 75% was CO2, 18% was methane, 4% was nitrous oxide, and 2% was fluorinated gases.
# This requires far-reaching, systemic changes on an unprecedented scale in energy, land, cities, transport, buildings, and industry.
# Methane emissions come from livestock, manure, rice cultivation, landfills, wastewater, and coal mining, as well as oil and gas extraction.
# Limiting global warming makes it much easier to achieve the UN's Sustainable Development Goals, such as eradicating poverty and reducing inequalities.
# This technology, carbon capture and storage (CCS), could have a critical but limited role in reducing emissions.
