# %% [markdown]
# <a href="https://colab.research.google.com/github/komalshelar16/Natural-Language-Processing/blob/main/NLP_Exp_2_Data_Acquisition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Text file

# %%
import pandas as pd
import csv
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0c06f64b-6222-4dd4-bd32-cb2b446483d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c06f64b-6222-4dd4-bd32-cb2b446483d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output = pd.read_csv('/content/simple.txt',sep='\t')

# %%
print(output)
# Out:
#   Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# 0  Sed do eiusmod tempor incididunt ut labore et ...
# 1  This sample TXT file is provided by Sample-Fil...

# %%
with open('/content/simple.txt', 'r', encoding='utf-8') as file:
  text=file.read()
print(text)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# This sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.

# %% [markdown]
# CSV file

# %%
files.upload()
# Out:
#      <input type="file" id="files-adeceb3e-90f0-41e5-abd2-f453eddc02e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-adeceb3e-90f0-41e5-abd2-f453eddc02e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
output1=pd.read_csv('/content/stroop_dataset.csv')

# %%
print(output1)
# Out:
#     SubjID gender  age  congruent_1  incongruent_1  nontext_1  congruent_2  \
# 0        1      m   39          326            825        272          326
# 1        2      m   38          706            956        762          708
# 2        3      m   36          365            627        479          451
# 3        4      m   33          522            819        447          289
# 4        5      m   43          472            381        487          518
# 5        6      f   30          671            581        648          614
# 6        7      m   27          424            671        393          469
# 7        8      f   31          313            236        491           74
# 8        9      m   31          525            680        580          293
# 9       10      f   32          517            666        392          491
# 10      11      f   23          555            618        568          379
# ...

# %% [markdown]
# PDF file

# %%
# !pip install PyPDF2
import PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.2 MB/s eta 0:00:00
# ...

# %%
p_file= open('/content/Neuroplasticity as a function of second language learning Anatomical changes in the human brain.pdf','rb')

# %%
reader=PyPDF2.PdfReader(p_file)
text=' '
for page in reader.pages:
  text+=page.extract_text()
print(text)
p_file.close()
# Out:
#  Review
# Neuroplasticity as a function of second language
# learning: Anatomical changes in the human brain
# Q8Ping Li*, Jennifer Legault and Kaitlyn A. Litcofsky
# Center for Brain, Behavior, and Cognition, Center for Language Science, Department of Psychology, Pennsylvania
# State University, United States Q1
# article info
# Article history:
# Received 18 January 2014Reviewed 31 March 2014Revised 22 April 2014Accepted 1 May 2014Action editor Costanza PapagnoPublished online xxx
# Keywords:
# NeuroplasticityDTIVBMSecond language acquisitionBilingualismabstract
# ...

# %% [markdown]
# Corpus

# %%
corpus = text + output.iloc[:, 0].str.cat(sep=' ')
print(corpus)
# Out:
#  Review
# Neuroplasticity as a function of second language
# learning: Anatomical changes in the human brain
# Q8Ping Li*, Jennifer Legault and Kaitlyn A. Litcofsky
# Center for Brain, Behavior, and Cognition, Center for Language Science, Department of Psychology, Pennsylvania
# State University, United States Q1
# article info
# Article history:
# Received 18 January 2014Reviewed 31 March 2014Revised 22 April 2014Accepted 1 May 2014Action editor Costanza PapagnoPublished online xxx
# Keywords:
# NeuroplasticityDTIVBMSecond language acquisitionBilingualismabstract
# ...

# %%
import requests
from bs4 import BeautifulSoup
input=requests.get('https://ubuntu.com/')

# %%
print(input)
# Out:
# <Response [200]>

# %%
input.content
# Out:
# b'<!DOCTYPE html>\n\n<html prefix="og: http://ogp.me/ns#"\n      class=""\n      lang="en"\n      dir="ltr">\n  <head>\n    <meta charset="UTF-8" />\n    <meta name="keywords" content="index, follow" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <title>\n      Enterprise Open Source and Linux\n    | Ubuntu</title>\n    <link rel="preconnect" href="https://res.cloudinary.com" />\n    <link rel="preconnect" href="https://assets.ubuntu.com" crossorigin />\n\n    <link rel="preconnect" href="https://www.googletagmanager.com" />\n    <link rel="dns-prefetch" href="https://www.googletagmanager.com" />\n    <link rel="preconnect" href="https://pagead2.googlesyndication.com" />\n    <link rel="dns-prefetch" href="https://pagead2.googlesyndication.com" />\n\n    <script src="https://assets.ubuntu.com/v1/703e23c9-lazysizes+noscript+native-loading.5.1.2.min.js"\n            defer></script>\n    <script src="/static/js/src/navigation.js?v=7519945" defer></sc
# ...

# %%
input.text
# Out:
# '<!DOCTYPE html>\n\n<html prefix="og: http://ogp.me/ns#"\n      class=""\n      lang="en"\n      dir="ltr">\n  <head>\n    <meta charset="UTF-8" />\n    <meta name="keywords" content="index, follow" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <title>\n      Enterprise Open Source and Linux\n    | Ubuntu</title>\n    <link rel="preconnect" href="https://res.cloudinary.com" />\n    <link rel="preconnect" href="https://assets.ubuntu.com" crossorigin />\n\n    <link rel="preconnect" href="https://www.googletagmanager.com" />\n    <link rel="dns-prefetch" href="https://www.googletagmanager.com" />\n    <link rel="preconnect" href="https://pagead2.googlesyndication.com" />\n    <link rel="dns-prefetch" href="https://pagead2.googlesyndication.com" />\n\n    <script src="https://assets.ubuntu.com/v1/703e23c9-lazysizes+noscript+native-loading.5.1.2.min.js"\n            defer></script>\n    <script src="/static/js/src/navigation.js?v=7519945" defer></scr
# ...

# %%
sp=BeautifulSoup(input.text,'html.parser')
sp
# Out:
# <!DOCTYPE html>
#
# <html class="" dir="ltr" lang="en" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="keywords"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>
#       Enterprise Open Source and Linux
#     | Ubuntu</title>
# <link href="https://res.cloudinary.com" rel="preconnect"/>
# <link crossorigin="" href="https://assets.ubuntu.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://pagead2.googlesyndication.com" rel="preconnect"/>
# <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <script defer="" src="https://assets.ubuntu.com/v1/703e23c9-lazysizes+noscript+native-loading.5.1.2.min.js"></script>
# <script defer="" src="/static/js/src/navigation.js?v=7519945"></script>
# ...

# %%
para = sp.find_all('p')

# %%
para
# Out:
# [<p class="p-notification__message">
#          Your submission was sent successfully!
#          <a href="#" onclick="location.href = document.referrer; return false;"><i class="p-notification__close">Close</i></a>
#  </p>,
#  <p class="p-notification__message">
#          Thank you for contacting us. A member of our team will be in touch shortly.
#          <a href="#" onclick="location.href = document.referrer; return false;"><i class="p-notification__close">Close</i></a>
#  </p>,
#  <p class="p-notification__message">
#          You have successfully unsubscribed!
#          <a href="#" onclick="location.href = ''; return false;"><i class="p-notification__close">Close</i></a>
#  </p>,
#  <p class="p-notification__message">
#          Thank you for signing up for our newsletter!
#          <br/>
#          In these regular emails you will find the latest updates about
# ...

# %%
para = sp.find_all('h1')

# %%
para
# Out:
# [<h1 class="u-no-margin--bottom" id="test-takeover-title">A CTO's guide to real-time Linux</h1>,
#  <h1 class="u-no-margin--bottom" id="takeover-title">Ubuntu 24.04 LTS Noble Numbat is available for download</h1>]

# %%
para = sp.get_text('h1')

# %%
para
# Out:
# "\nh1\nh1\nh1\nh1\nh1\nh1\n      Enterprise Open Source and Linux\n    | Ubuntuh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\n        Your submission was sent successfully!\n        h1Closeh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\n        Thank you for contacting us. A member of our team will be in touch shortly.\n        h1Closeh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\n        You have successfully unsubscribed!\n        h1Closeh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\n        Thank you for signing up for our newsletter!\n        h1\n        In these regular emails you will find the latest updates about\n        Ubuntu and upcoming events where you can meet our team.h1Closeh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\nh1\n        Your preferences have been successfully updated. h1Close notificationh1\nh1\nh1\nh1\nh1\nh1\
# ...

# %%
takeover_div = sp.find('div', id='takeover-animation')
if takeover_div:
    print(takeover_div.get_text(separator=' ', strip=True))
else:
    print("Div with id 'takeover-animation' not found.")
# Out:
# Ubuntu 24.04 LTS Noble Numbat is available for download Discover the latest and greatest features in our most recent long term supported release. Download for free Read the deep dive ›
